# %% [markdown]
# # 📘 Python OOP Workshop (Colab)
# ## หัวข้อที่ 1: บทนำสู่แนวคิด OOP และภาษา Python
# - ทบทวนโครงสร้างภาษา Python
# - เปรียบเทียบ Procedural vs OOP
# - แนะนำแนวคิด Class และ Object
#
# ---

# %%
# Procedural Programming Example
name = "Alice"
score = 85

def show_student(name, score):
    print(f"Student: {name}, Score: {score}")

show_student(name, score)

# %% [markdown]
# ### ✅ เปรียบเทียบกับ OOP

# %%
# ✅ OOP Example with Class
class Student:
    def __init__(self, name, score):
        self.name = name
        self.score = score

    def show_info(self):
        print(f"Student: {self.name}, Score: {self.score}")

student1 = Student("Alice", 90)
student1.show_info()

# %% [markdown]
# ---
# ## ✏️ Workshop: เขียนโปรแกรมสร้างคลาส Student พร้อม method แสดงข้อมูล
# **ให้ผู้เรียนลองแก้ไขโค้ดด้านล่างนี้**

# %%
# 🔧 ลองทำดู!
class Student:
      def __init__(self,name,age,grade,city):
        self.name   = name
        self.age = age
        self.grade = grade
        self.city = city

      def display_info(self):
         print(f"ชื่อ: {self.name}")
         print(f"อายุ: {self.age}")
         print(f"เกรด: {self.grade}")
         print(f"เมือง: {self.city}")

student1 = Student("แมน",20,"A","กรุงเทพฯ")
student1.display_info()
pass

# %% [markdown]
# # 🏎️ หัวข้อที่ 2: การออกแบบคลาสและอ็อบเจ็กต์ (Class & Object Design)
# - Attributes & Methods
# - Constructor (__init__)
# - Instance vs Class Variable
#
# ---

# %%
# Class & Object Example
class Car:
    brand = "Unknown"  # Class Variable

    def __init__(self, model, color):
        self.model = model
        self.color = color

    def show_info(self):
        print(f"Car: {self.model}, Color: {self.color}, Brand: {self.brand}")

car1 = Car("Model S", "White")
car1.brand = "Tesla"
car1.show_info()

# %% [markdown]
# ### ✏️ แบบฝึกหัด: ออกแบบคลาส Car และทดสอบการสร้างอ็อบเจ็กต์

# %%
# ลองออกแบบ class Car พร้อม attributes และ methods ของคุณเอง
class Car:
    def __init__(self,model,colors,wheel,brand):
        self.colors = colors
        self.wheel = int(wheel)
        self.brand = brand
        self.model = model

    def show_more(self):
        print(f"Car : {self.model} Colors : {self.colors} Wheel : {self.wheel} Brand : {self.brand}")
car1 = Car("Model A " , "Red " ,4,"Tesla")
car1.show_more()
pass
